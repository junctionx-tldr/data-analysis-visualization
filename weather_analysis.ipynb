# %%
#Check out the weather file

import pandas as pd

weather = pd.read_csv('Helsinki weather data_english.csv',sep=';')

# %%
weather.loc[(weather['Year'] == 2019) & (weather['Month'] == 8)]
# Out:
#       Year  Month  Day  Time Time Zone  Amount of clouds  (1/8)  \
# 4464  2019      8    1   0.0       UTC                      5.0
# 4465  2019      8    1   0.1       UTC                      3.0
# 4466  2019      8    1   0.2       UTC                      5.0
# 4467  2019      8    1   0.3       UTC                      5.0
# 4468  2019      8    1   0.4       UTC                      7.0
# ...    ...    ...  ...   ...       ...                      ...
# 8923  2019      8   31  23.1       UTC                      0.0
# 8924  2019      8   31  23.2       UTC                      0.0
# 8925  2019      8   31  23.3       UTC                      0.0
# 8926  2019      8   31  23.4       UTC                      0.0
# 8927  2019      8   31  23.5       UTC                      0.0
#
#      Air pressure (msl) (hPa)  Relative humidity (%) Rain intensity (mm/h)  \
# 4464               1015.04.00                   63.0                     0
# ...

# %%
#lets put in some visualizations

weather_2019 = weather[weather['Year'] == 2019]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, yerr=menStd)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, yerr=womenStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()

# %%
#bar chart showing visibility in 2019
plt.bar(weather_2019['Month'], weather_2019['Visibility (m)'])
# Out:
# <BarContainer object of 13249 artists>

# %%
weather_2019.describe()
# Out:
#           Year         Month           Day          Time  \
# count  13249.0  13249.000000  13249.000000  13249.000000
# mean    2019.0      7.989282     15.835837     11.749113
# std        0.0      0.814390      8.855165      6.925045
# min     2019.0      7.000000      1.000000      0.000000
# 25%     2019.0      7.000000      8.000000      5.500000
# 50%     2019.0      8.000000     16.000000     11.500000
# 75%     2019.0      9.000000     23.000000     17.500000
# max     2019.0     10.000000     31.000000     23.500000
#
#        Amount of clouds  (1/8)  Relative humidity (%)  Depth of snow (cm)  \
# count             13216.000000           13216.000000             13216.0
# mean                  3.369174              74.785487                -1.0
# std                   3.154872              15.470360                 0.0
# min                   0.000000              25.000000                -1.0
# 25%                   0.000000              65.000000                -1.0
# ...
